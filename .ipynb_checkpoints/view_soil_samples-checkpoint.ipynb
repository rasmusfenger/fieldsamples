# %%
########################################################
# Sites:
# 1 = Sandnes
# 2 = Iffiartafik
# 3 = Qoornoq
# 4 = Ersaa
# 5 = Kangeq
# 6 = all
# 7 = all_separate
#
# Types:
# Natural = 1
# Cultural = 2
# both = 3
#
# Variables:
# Variable,Title,Sheet,Column,xname,yname,depth
# 1,Water content,Soil samples,32,% water,depth (cm),yes
# 2,Water content,Soil samples,34,% water,depth (cm),yes
# 3,Water content,Soil samples,42,Vol. % water,depth (cm),yes
# 4,pH,Wet analysis all,11,pH,depth (cm),yes
# 6,Soil weight,Soil samples,9,weight (g),depth (cm),yes
# 7,Remaining soil,Soil samples,19,weight (g),depth (cm),yes
# 8,Waste,Soil samples,20,weight (g),depth (cm),yes
# 10,Roots < 1mm,Roots all,10,dry weight (g)/100cm3,depth (cm),yes
# 11,Roots > 1 mm,Roots all,11,dry weight (g)/100cm3,depth (cm),yes
# 12,Horse tail,Roots all,12,dry weight (g)/100cm3,depth (cm),yes
# 13,Roots < 1mm 2016,Roots all,29,dry weight kg/m$^3$,depth (cm),yes
# 15,Roots total incl HT-m2,Roots all,31,dry weight kg/m$^2$,depth (cm),yes
# 16,Roots total excl HT,Roots all,24,dry weight g/100cm3,depth (cm),yes
# 17,Roots total incl HT,Roots all,25,dry weight g/100cm3,depth (cm),yes
# 18,Roots total excl HT,Roots all,26,dry weight kg/m$^3$,depth (cm),yes
# 19,Roots total incl HT,Roots all,27,dry weight kg/m$^3$,depth (cm),yes
# 20,Biomass,Biomass,14,Biomass (g/20 cm$^2$),none,no
# 21,Biomass,Biomass,20,Biomass (kg/m$^2$),none,no
# 22,NDVI handheld,Biomass,19,ndvi,none,no
# 23,LAI,Veg analysis,13,LAI,none,no
# 30,Phosphorus-liquid,Olsen P,18,Olsen-P (mg/l),depth (cm),yes
# 31,Phosphorus-DWsoil,Olsen P,23,Olsen-P (mg/kg DW),depth (cm),yes
# 32,Phosphorus-vol,Olsen P,25,P (g Olsen-P/m$^3$),depth (cm),yes
# 35,Phosphorus-liquid-gapf,Olsen Olsen-P,26,P (mg/l),depth (cm),yes
# 36,Phosphorus-gapf,Olsen P,28,Olsen-P mg/cm$^3$,depth (cm),yes
# 37,Phosphorus,Olsen P,29,Olsen-P g/m$^3$,depth (cm),yes
# 38,Phosphorus,Olsen P ny,26,Olsen-P g/m$^3$,depth (cm),yes
# 39,Phosphorus-gapf,Olsen P ny,27,Olsen-P (g/m$^3$),depth (cm),yes
# 34,Phosphorus-gapf-m2,Olsen P ny,28,Olsen-P (g/m$^2$),depth (cm),yes
# 40,NO3-liquid,Wet analysis 2016,14,NO$_3$ (ug/L),depth (cm),yes
# 41,NH4-liquid,Wet analysis 2016,24,NH$_4$ (ug/L),depth (cm),yes
# 42,TOC-liquid,Wet analysis 2016,34,TOC (mg/L),depth (cm),yes
# 43,TN-liquid,Wet analysis 2016,43,TN (mg/L),depth (cm),yes
# 44,DON-liquid,Wet analysis 2016,52,DON (ug/L),depth (cm),yes
# 45,NO$_3$ wet analysis-m2,Wet analysis all,16,NO$_3^-$-N (g/m$^2$),depth (cm),yes
# 46,NH$_4$ wet analysis-m2,Wet analysis all,17,NH$_4^+$-N (g/m$^2$),depth (cm),yes
# 47,DOC wet analysis-m2,Wet analysis all,18,DOC (g/m$^2$),depth (cm),yes
# 48,TDN wet analysis-m2,Wet analysis all,19,TDN (g/m$^2$),depth (cm),yes
# 49,DON wet analysis-m2,Wet analysis all,20,DON (g/m$^2$),depth (cm),yes
# 50,NO$_3$ wet analysis-gapf,Wet analysis 2016,23,NO$_3$ (g/m$^3$),depth (cm),yes
# 51,NH$_4$ wet analysis-gapf,Wet analysis 2016,33,NH$_4$ (g/m$^3$),depth (cm),yes
# 52,TOC wet analysis-gapf,Wet analysis 2016,42,TOC (g/m$^3$),depth (cm),yes
# 53,TN wet analysis-gapf,Wet analysis 2016,51,TN (g/m$^3$),depth (cm),yes
# 54,DON wet analysis-gapf,Wet analysis 2016,60,DON (g/m$^3$),depth (cm),yes
# 55,NO$_3$ wet analysis,Wet analysis all,5,NO$_3^-$-N (g/m$^3$),depth (cm),yes
# 56,NH$_4$ wet analysis,Wet analysis all,6,NH$_4^+$-N (g/m$^3$),depth (cm),yes
# 57,TOC wet analysis,Wet analysis all,7,DOC (g/m$^3$),depth (cm),yes
# 58,TN wet analysis,Wet analysis all,8,TDN (g/m$^3$),depth (cm),yes
# 59,DON wet analysis,Wet analysis all,9,DON (g/m$^3$),depth (cm),yes
# 60,N% total in soil,C N analysis,8,N% total,depth (cm),yes
# 61,C% total in soil,C N analysis,9,C% total,depth (cm),yes
# 62,N15 ‰ AIR in soil,C N analysis,10,$\delta^{15}$N (‰ AIR),depth (cm),yes
# 63,C13 ‰ PDB in soil,C N analysis,11,$\delta^{13}$C (‰ PDB),depth (cm),yes
# 64,C_N ratio in soil,C N analysis,13,C-N ratio,depth (cm),yes
# 65,N total in soil,C N analysis,16,Total N kg/m$^3$,depth (cm),yes
# 70,Green uav,uav,4,Green,none,no
# 71,Red uav,uav,5,Red,none,no
# 72,Rededge uav,uav,6,Rededge,none,no
# 73,Nir uav,uav,7,Nir,none,no
# 74,NDVI uav,uav,8,NDVI,none,no
# 75,OSAVI uav,uav,9,OSAVI,none,no
# 76,NDRE uav,uav,10,NDRE,none,no
# 80,P mean,mix,6,P g/m$^3$,none,no
# 81,prediction_all_conc,mix,31,predicted,none,no
# 82,prediction_persite_conc,mix,35,predicted,none,no
# 83,prediction_all_pool,mix,40,predicted,none,no
# 84,prediction_persite_pool,mix,44,predicted,none,no
# 90,PC1,Biomass,21,PC 1 (37.7%),none,no
# 91,PC2,Biomass,22,PC 2 (21.6%),none,no
# 92,PC3,Biomass,23,PC 3,none,no
# 93,PC4,Biomass,24,PC 4,none,no

# plot modes:
# 1 = all plots

# 2 = pool natural/cultural plots together and plot mean
# 2.1 = add std as error plot
# 2.2 = add std as shaded area
# 2.3 = compact with standard deviation
# 2.4 = compact with standard error
# 2.5 = compact with standard error - modified y-axis to per m2

# 3 = Scatter plot
# 3.1 = add ellipse (2 st.dev.)

# 4 = Scatter plot mean
# 4.1 = add std error bar on y-axis
# 4.2 = add std error bar on x-axis
# 4.3 = add std error bar on both axes

#########################################################

# %%
# Plot figures

from plotfunctions import *
# %matplotlib inline
inFile = 'data/Lab_sheet_v9.67.xlsx'

sites = 6
types = 3
plotmode = 2.5

variable1 = 39
mod1 = False
di1 = False

variable2 = 91
mod2 = False
di2 = False

ylim = False #[-3.5,3]
xlim = False #[-4,3.2]

reg = False

#savefig = '/Users/rasmus/Google Drive/Phd/Skrivning/paper 1/figures/raw'
savefig = False
title = ''#False

# Legend can be True/False/'special_1'/'special_2'
# For figure with PCA analysis use 'special_1'
# For small legend in plot 2.4 and 2.5 use'special_2'.
legend = 'special_2'

grid = False

# Used sizes: [2.5,2.5], [6,6] (figure 3), [14, 2.5] (figure 4)
size = [14, 2.5]

# add text note on figure
# [x,y,string,fontsize]
textnote = [-5.2, 1.05, 'B', 14]

################
var1 = Variable(variable1, mod1, di1)
var2 = Variable(variable2, mod2, di2)
if sites == 7:
    for num in range(1,7):
        plot(inFile, num, types, var1, var2, plotmode, xlim, ylim, reg, savefig, title, legend, size, grid, text)
else:
    plot(inFile, sites, types, var1, var2, plotmode, xlim, ylim, reg, savefig, title, legend, size, grid, textnote)
# Out:
# /Users/rasmus/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:83: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Users/rasmus/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:117: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
# Plot nutrient measurements in relation to depth - figure 4 in article
# NB: NO3 with title = True, P with legend = 'special_2'

from plotfunctions import *
# %matplotlib inline
inFile = 'data/Lab_sheet_v9.67.xlsx'

sites = 6
types = 3
plotmode = 2.5

# variables: 55, 56, 39 (NO3, NH4, P)

variable1 = 55
mod1 = False
di1 = False
variable2 = 0
mod2 = False
di2 = False

savefig = False#'/Users/rasmus/Google Drive/Phd/Skrivning/paper 1/figures/raw'
title = True
legend = 'special_2'# False
size = [14, 2.5]
textnote = [-5.2, 1.05, 'A', 14]#[x,y,string,fontsize]
xlim = False
ylim = False
reg = False
grid = False

################
var1 = Variable(variable1, mod1, di1)
var2 = Variable(variable2, mod2, di2)
plot(inFile, sites, types, var1, var2, plotmode, xlim, ylim, reg, savefig, title, legend, size, grid, textnote)

# %%
# Merge A, B, C in figure 4 to one file.
import sys
from PIL import Image
import os

fileList = []
path = '/Users/rasmus/Google Drive/Phd/Skrivning/paper 1/figures/raw/plotmode_2.5'
fileList.append(os.path.join(path,'NO$_3$ wet analysis-m2 all sites.png'))
fileList.append(os.path.join(path,'NH$_4$ wet analysis-m2 all sites.png'))
fileList.append(os.path.join(path,'Phosphorus-gapf-m2 all sites.png'))

images = map(Image.open, fileList)
widths, heights = zip(*(i.size for i in images))

total_width = min(widths)
max_height = sum(heights)

new_im = Image.new('RGB', (total_width, max_height))

y_offset = 0
for im in images:
  new_im.paste(im, (0,y_offset))
  y_offset += im.size[1]

new_im.save(os.path.join(path,'test2.tif'))

# %%
from stattest import *
inFile = 'data/Lab_sheet_v9.67.xlsx'
# t-test cultural vs natural
sites = 6
variable = 56
mod = False
di = 35
#savetxt = '/Users/rasmus/Google Drive/Phd/Field work 2016/figures/t-test/cultural vs natural'
savetxt = None
printtxt = True
var = Variable(variable, mod, di)
################
ttest_stype(inFile, sites, var, savetxt, printtxt, equal_var=False)
# Out:
# NH$_4$ wet analysis t-test
# Natural vs Cultural
#
# Sandnes
# 	t = -0.443     p = 0.668     n = 6     not significant
# Iffiartafik
# 	t = -1.977     p = 0.077     n = 6     not significant
# Qoornoq
# 	t = -3.518     p = 0.017     n = 6     significant
# Ersaa
# 	t = -3.434     p = 0.025     n = 5     significant
# Kangeq
# 	t = -3.923     p = 0.003     n = 6     significant

# %%
# For inspection of data manually
from loaddata import *
inFile = 'data/Lab_sheet_v9.67.xlsx'
site = 4
sitetype = 3
groupby = 'plot'

# variable:
# P = 39
# NO3 = 55
variable = 19
mod = False
di = 35
###############
if site == 6:
    sList = [1,2,3,4,5]
else:
    sList = [site]
for s in sList:
    var = Variable(variable, mod, di)
    ds = getData(inFile, var, s, sitetype, groupby=groupby, mod=var.mod, di=var.di)
    ds.data = pool_plot(ds.data)
    listA = ds.data[0].observation
    listB = ds.data[1].observation

    #print "\n%s - %s:\t" %(ds.data[1].site, ds.data[1].sitetype)
    for b in listB:
        print b
    #print "%s - %s:\t" %(ds.data[0].site, ds.data[0].sitetype)
    for a in listA:
        print a
# Out:
# 3.17607142857
# 4.28235714286
# nan
# 4.84321428571
# 3.66742857143
# 4.44821428571
# 0.952714285714
# 1.37578571429
# 0.956857142857
# 0.939214285714
# 0.960357142857
# 1.31542857143

# %%
# Export depth integrated mean values and std-error for making table Table 1 in article.
# The produced textfile should be imported as text in Excel.

from loaddata import *
from dictionaries import *
import numpy as np
inFile = 'data/Lab_sheet_v9.67.xlsx'
outFile = '/Users/rasmus/Google Drive/Phd/Skrivning/paper 1/figures/tables/datatable_suppl_1_test.txt'
siteList = [5,4,3,2,1]
sitetype = 3
groupby = 'plot'

# NO3, NH4, P, Biomass above, Biomass below
#variableList = [55, 56, 39, 21, 19]

# DON, TDN, DOC 
variableList = [59, 58, 57]

# CN, 15N, 13C, vol% water, pH (depth weighed)
#variableList = [64, 62, 63, 3, 4]

mod = False
di = False
allArch = []
###############
with open(outFile, 'w') as f1:
    for variable in variableList:
        var = Variable(variable, mod, di)
        try:
            f1.write(',' + var.title)
        except:
            print 'Could not write: ', var.title
    for site in siteList:
        print siteDict[site]
        f1.write('\n' + siteDict[site])
        for sitetype in [2,1]:
            firstRun = True
            for variable in variableList:
                if variable == 21:
                    di = False
                else:
                    di = 35
                var = Variable(variable, mod, di)
                ds = getData(inFile, var, site, sitetype, groupby=groupby, mod=var.mod, di=var.di)
                ds.data = pool_plot(ds.data)
                dataList = ds.data[0].observation

                if firstRun and sitetype==1:
                    f1.write('\n')
                f1.write(',=' + str(round(np.nanmean(dataList),2)) + '&CHAR(177)&' + str(round(np.nanstd(dataList)/np.sqrt(len(dataList)),2)))

                firstRun = False
                if sitetype == 2:
                    allArch.append(dataList)
print 'finished'
# Out:
# Kangeq
# Ersaa
# Qoornoq
# Iffiartafik
# Sandnes
# finished

# %%
# plot functional classes - figure 3 A-B in article
# Data derive from Lab_sheet_v9.67, Sheet: "Veg analysis"

# Total percentage cover: row 78-88
dataNat = [['Kangeq',37,6,84,19,0,24],
        ['Ersaa', 1,0,123,34,0,34],
        ['Qoornoq',0,1,104,161,0,0],
        ['Iffiartafik', 55,3,14,169,47,35],
        ['Sandnes',187,29,0,63,4,49]]

dataCul = [['Kangeq',308,23,0,0,0,8],
           ['Ersaa',396,8,0,30,95,1],
           ['Qoornoq',288,33,0,0,151,0],
           ['Iffiartafik',265,0,0,14,3,0],
           ['Sandnes',439,7,0,0,189,0]]

# Total coverage percentages for each plot (used to get errorbars - stdev)
# Col: M (Total LAI) row 3-63. 
laiNat = [[128,124,144,180,252,192],
          [184,112,236,232,212,180],
          [296,216,392,224,196,272],
          [200,212,244,500,496,284],
          [364,384,336,292,428,196]]

laiCul = [[304,324,276,344,340,448],
          [444,452,404,656,708,520],
          [332,288,616,556,580,460],
          [244,256,392,288,196,320],
          [828,1004,692,528,328,436]]

# to get standard error (numbers calculated in Col L, row 79-88)
x = [0,1,2,3,4]
yNat = [170,193,266,323,333]
stderrorNat = [19.89,18.75,29.43,56.71,33.19]
yCul = [339,531,472,283,636]
stderrorCul = [24.03,50.67,55.69,27.74,103.59]

labels = ['Site', 'Graminoids', 'Forbs', 'Evergreen shrubs', 'Deciduous shrubs', 'Horsetail', 'Moss']
xticks = ['Kangeq', 'Ersaa','Qoornoq','Iffiartafik','Sandnes']

import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap
matplotlib.style.use('ggplot')
from pandas import DataFrame

sns.set_style("white")
colors = sns.color_palette("Set2", n_colors=len(labels))
cmap1 = LinearSegmentedColormap.from_list("my_colormap", colors)

# change font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']

fig, axes = plt.subplots(nrows=1, ncols=2, sharey=True)
# plot invisible bars with visible errobars
# standard error
ax=axes[0].errorbar(x, yNat, yerr=stderrorNat, ecolor='k', elinewidth=0.7, capsize=3, capthick=0.7, fmt='none')
# plot stacked bars
df1 = DataFrame(data=dataNat)
df1.columns = labels
df1.set_index('Site')
df1.plot(ax=axes[0], kind='bar', stacked=True, colormap=cmap1, rot=0, title='Reference area', edgecolor="0.02")

ax=axes[1].errorbar(x, yCul, yerr=stderrorCul, ecolor='k', elinewidth=0.7, capsize=3, capthick=0.7, fmt='none')
df2 = DataFrame(data=dataCul)
df2.columns = labels
df2.set_index('Site')
df2.plot(ax=axes[1], kind='bar', stacked=True, colormap=cmap1, rot=0, legend=False, title='Archaeological site', edgecolor=".2")

axes[0].set_ylabel("Plant cover (%)")
axes[0].set_xticklabels(xticks)
axes[1].set_xticklabels(xticks)
for axis in ['top','bottom','left','right']:
    axes[0].spines[axis].set_linewidth(0.7)
    axes[1].spines[axis].set_linewidth(0.7)
plt.gcf().set_size_inches(12,6)
#plt.savefig('/Users/rasmus/Google Drive/Phd/Skrivning/paper 1/figures/allsites_veganalysis_eb.png', dpi=600)
plt.show()

# %%
# Plot principal component analysis - figure 3 C in article
# Legend was added manually in powerpoint

from plotfunctions import *
# %matplotlib inline
inFile = 'data/Lab_sheet_v9.67.xlsx'

sites = 6
types = 3
plotmode = 3.1

variable1 = 90
mod1 = False
di1 = False
variable2 = 91
mod2 = False
di2 = False

ylim = [-3.5,3]
xlim = [-4,3.2]
savefig = False
title = ''
legend = False
grid = True
size = [6, 6]
reg = False
textnote = False

################
var1 = Variable(variable1, mod1, di1)
var2 = Variable(variable2, mod2, di2)
plot(inFile, sites, types, var1, var2, plotmode, xlim, ylim, reg, savefig, title, legend, size, grid, textnote)
# Out:
# /Users/rasmus/anaconda/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: The mpl_toolkits.axes_grid module was deprecated in version 2.1. Use mpl_toolkits.axes_grid1 and mpl_toolkits.axisartist provies the same functionality instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# loaddata.py:101: FutureWarning: the 'parse_cols' keyword is deprecated, use 'usecols' instead
#   df = pd.read_excel(inFile, var.sheet, header=2, parse_cols='A:BZ', na_values='none')

# %%
# plot loading - figure 3 D in article
# Data derive from analysis (Latentix)
pc1 = [-0.612376, -0.116617, 0.455645, 0.363332, -0.437095, 0.284115]
pc2 = [0.0695434, -0.702752, 0.1605, 0.285802, 0.0913563, -0.620898]

labels = ['Graminoids', 'Forbs', 'Evergreen', 'Deciduous', 'Horsetail', 'Moss']

import matplotlib.pyplot as plt
# %matplotlib inline

# change font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']

plt.figure(figsize=(6,6))
plt.plot(pc1,pc2, 'ko', markerfacecolor='white', markeredgecolor='k', markeredgewidth=1)
plt.plot(0,0, 'ko')

ax = plt.axes()
for i in range(len(pc1)):
    ax.arrow(0, 0, pc1[i], pc2[i], head_width=0.03, label=labels, head_length=0.06, color='k', ls='-', lw=1, fill=True, length_includes_head=True)
    plt.annotate(labels[i], xy=(pc1[i],pc2[i]), xytext=(34, 10),
        textcoords='offset points', ha='right', va='bottom')
ax.set_xlim(-0.8,0.6)
ax.set_ylim(-0.8,0.4)
#ax.set_xlabel('PC 1 (29.1%)')
#ax.set_ylabel('PC 2 (20.3%)')
ax.set_xlabel('PC 1 (37.7%)')
ax.set_ylabel('PC 2 (21.6%)')
plt.gca().set_axisbelow(True)
plt.gca().grid()
plt.gcf().set_size_inches(6,6)
#plt.savefig('/Users/rasmus/Google Drive/Phd/Skrivning/paper 1/figures/raw/loading_noleymus.png', bbox_inches = 'tight', dpi=1000)
plt.show()

# %%
from testsfunc import *
inFile = 'data/Lab_sheet_v9.67.xlsx'
runtest(inFile, savefig=False)
# Out:
# /Users/rasmus/anaconda/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: The mpl_toolkits.axes_grid module was deprecated in version 2.1. Use mpl_toolkits.axes_grid1 and mpl_toolkits.axisartist provies the same functionality instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# loaddata.py:101: FutureWarning: the 'parse_cols' keyword is deprecated, use 'usecols' instead
#   df = pd.read_excel(inFile, var.sheet, header=2, parse_cols='A:BZ', na_values='none')
# testing plotmode 1
# testing plotmode 2
# /Users/rasmus/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:83: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# /Users/rasmus/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:117: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# testing plotmode 3
# testing plotmode 4
# ...
