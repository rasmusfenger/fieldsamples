# %%
import sys
sys.path.append('/Users/rasmus/PycharmProjects/fieldsamples')
from plotfunctions import *
# %matplotlib inline

inFile = '/Users/rasmus/Google Drive/Phd/Field work 2016/Lab_sheet_v9.27.xlsx'
sites = 7
types = 3
variable_1 = 31
variable_2 = 41
plotmode = 2.2
reg = True

################
if sites == 7:
    for num in range(1,7):
        plot(inFile, num, types, variable_1, variable_2, plotmode, reg)
else:
    plot(inFile, sites, types, variable_1, variable_2, plotmode, reg)
